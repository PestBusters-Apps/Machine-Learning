# %%
# Import the necessary libraries
# %pip install ultralytics
from ultralytics import YOLO
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# Define the paths
model_path = "final_train.pt"
image_path = "imageye___-_b_6579_jpeg.rf.da0f4fd4aa4d89dc29900060a730c3aa.jpg"

# Check if paths exist
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model path '{model_path}' does not exist.")
if not os.path.exists(image_path):
    raise FileNotFoundError(f"Image path '{image_path}' does not exist.")

# Load a pretrained YOLOv8 model
model = YOLO(model_path)

# Predict on an image
results = model.predict(source=image_path, conf=0.25, save=False)  # Set save=False to avoid saving to disk

# Extract the annotated image from results
annotated_image = results[0].plot()

# Display the annotated image using matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Detection Results")
plt.show()
# Out:
# image 1/1 d:\POLITEKNIK NEGERI JAKARTA\CAPSTONE\MachineLearning\YOLO\imageye___-_b_6579_jpeg.rf.da0f4fd4aa4d89dc29900060a730c3aa.jpg: 640x640 2 ulats, 348.7ms
# Speed: 2.0ms preprocess, 348.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
